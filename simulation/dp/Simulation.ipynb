# %% [markdown]
# # **Simple integration of DP Langevin equation**

# %% [markdown]
# Run a basic DP simulation.

# %% [markdown]
# <hr>
#
# ## Preliminaries

# %%
from essentials import *
langevin.__version__
# Out:
# '2025.11.14a2'

# %% [markdown]
# <hr>
#
# ## Simulation

# %%
sim_name: str = "a1p18855_b1_D0p04_η1_x31_y31_Δx1_Δt0p1"
info_path: list[str] = [pardir, pardir, "experiments", sim_name]
info: dict
_, info = read_info(info_path, dplvn)
_
# Out:
# '../../experiments/a1p18855_b1_D0p04_η1_x31_y31_Δx1_Δt0p1'

# %%
info["Misc"]["n_round_Δt_summation"] = 15

# %%
sim = Simulation(
    name=sim_name, path=info_path, info=info, 
    do_snapshot_grid=False, do_verbose=True,
)
#  "a1p18855_b1_D0p04_η1_x62_y62_Δx1_Δt0p1"
#  "a1p18855_b1_D0p04_η1_x125_y125_Δx1_Δt0p1"
#  "a1p18855_b1_D0p04_η1_x250_y250_Δx1_Δt0p1"
#  "a1p18855_b1_D0p04_η1_x500_y500_Δx1_Δt0p1"
#  "a1p18855_b1_D0p04_η1_x1000_y1000_Δx1_Δt0p1"
#  "a1p18855_b1_D0p04_η1_x2000_y2000_Δx1_Δt0p1"
sim.misc["name"]
# Out:
# 'a1p18855_b1_D0p04_η1_x31_y31_Δx1_Δt0p1'

# %%
sim.initialize()
# Out:
# linear: 1.18855
# quadratic: 1
# diffusion: 0.04
# noise: 1
# t_final: 10000
# dx: 1
# dt: 0.1
# random_seed: 1
# grid_dimension: 2d
# grid_size: 31 31
# n_cells: 961
# grid_topologies: x edge:bounded; y edge:bounded
# boundary_conditions: x0 edge:floating, x1 edge:floating; y0 edge:floating, y1 edge:floating
# bc_values: 0 0 0 0
# initial_condition: uniform random values
# ic_values: 0 10
# integration_method: Runge-Kutta

# %%
sim.analysis["n_epochs"]
# Out:
# 100001

# %%
sim.run()
# Out:
# 100%|██████████| 501/501 [00:13<00:00, 38.11it/s]

# %% [markdown]
# <hr>
#
# ## Post-processing

# %%
sim.plot()

# %%
display(sim.graphs.fdict["ρ_t_loglog"])

# %%
sim.save(dplvn, do_verbose=True,)
# Out:
# Outfo/graphs/videos/data path:  ['..', '..', 'experiments', 'a1p18855_b1_D0p04_η1_x31_y31_Δx1_Δt0p1']
# 100%|██████████| 2/2 [00:00<00:00,  4.60it/s]
